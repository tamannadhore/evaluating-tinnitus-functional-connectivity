# %%
# libraries
from nilearn import datasets
from nilearn import image as nimg
from nilearn import plotting as nplot
import nibabel as nib
import numpy as  np
import numpy.linalg as npl
from pathlib import Path
# %matplotlib inline
import os 
import matplotlib.pyplot as plt

# %%
# load subject fMRI scan
basedir = Path("/data/hcp_working_folder/tdhore2")
datadir = basedir / "subj/106319/func" 
img = nib.load(datadir / 'rfMRI_REST1_LR.nii.gz')

# load atlas
imgdir = basedir / "schaefer_2018"
imgname = "Schaefer2018_400Parcels_17Networks_order_FSLMNI152_2mm.nii.gz"
base_img = nib.load(imgdir / imgname)

# %%
# ROI values for specific networks 
#DAN_col = [59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283]
#LN_col = [108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323]
#default_col = [148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389]

# %%
# finding coordinates of each ROI in default network
arr = np.array(base_img.dataobj)
coords1 = np.where(arr == 149)
coords2 = np.where(arr == 150)
coords3 = np.where(arr == 151)
coords4 = np.where(arr == 152)
coords5 = np.where(arr == 153)
coords6 = np.where(arr == 154)
coords7 = np.where(arr == 155)
coords8 = np.where(arr == 156)
coords9 = np.where(arr == 157)
coords10 = np.where(arr == 158)
coords11 = np.where(arr == 159)
coords12 = np.where(arr == 160)
coords13 = np.where(arr == 161)
coords14 = np.where(arr == 162)
coords15 = np.where(arr == 163)
coords16 = np.where(arr == 164)
coords17 = np.where(arr == 165)
coords18 = np.where(arr == 166)
coords19 = np.where(arr == 167)
coords20 = np.where(arr == 168)
coords21 = np.where(arr == 169)
coords22 = np.where(arr == 170)
coords23 = np.where(arr == 171)
coords24 = np.where(arr == 172)
coords25 = np.where(arr == 173)
coords26 = np.where(arr == 174)
coords27 = np.where(arr == 175)
coords28 = np.where(arr == 176)
coords29 = np.where(arr == 177)
coords30 = np.where(arr == 178)
coords31 = np.where(arr == 179)
coords32 = np.where(arr == 180)
coords33 = np.where(arr == 181)
coords34 = np.where(arr == 182)
coords35 = np.where(arr == 183)
coords36 = np.where(arr == 184)
coords37 = np.where(arr == 185)
coords38 = np.where(arr == 186)
coords39 = np.where(arr == 187)
coords40 = np.where(arr == 188)
coords41 = np.where(arr == 189)
coords42 = np.where(arr == 190)
coords43 = np.where(arr == 191)
coords44 = np.where(arr == 192)
coords45 = np.where(arr == 193)
coords46 = np.where(arr == 194)
coords47 = np.where(arr == 358)
coords48 = np.where(arr == 359)
coords49 = np.where(arr == 360)
coords50 = np.where(arr == 361)
coords51 = np.where(arr == 362)
coords52 = np.where(arr == 363)
coords53 = np.where(arr == 364)
coords54 = np.where(arr == 365)
coords55 = np.where(arr == 366)
coords56 = np.where(arr == 367)
coords57 = np.where(arr == 368)
coords58 = np.where(arr == 369)
coords59 = np.where(arr == 370)
coords60 = np.where(arr == 371)
coords61 = np.where(arr == 372)
coords62 = np.where(arr == 373)
coords63 = np.where(arr == 374)
coords64 = np.where(arr == 375)
coords65 = np.where(arr == 376)
coords66 = np.where(arr == 377)
coords67 = np.where(arr == 378)
coords68 = np.where(arr == 379)
coords69 = np.where(arr == 380)
coords70 = np.where(arr == 381)
coords71 = np.where(arr == 382)
coords72 = np.where(arr == 383)
coords73 = np.where(arr == 384)
coords74 = np.where(arr == 385)
coords75 = np.where(arr == 386)
coords76 = np.where(arr == 387)
coords77 = np.where(arr == 388)
coords78 = np.where(arr == 389)
coords79 = np.where(arr == 390)

# setting default network coordinates with a value of 1 while other ROIs remain with a value of 0
x = np.zeros((91, 109, 91))
x[coords1] = 1
x[coords2] = 1
x[coords3] = 1
x[coords4] = 1
x[coords5] = 1
x[coords6] = 1
x[coords7] = 1
x[coords8] = 1
x[coords9] = 1
x[coords10] = 1
x[coords11] = 1
x[coords12] = 1
x[coords13] = 1
x[coords14] = 1
x[coords15] = 1
x[coords16] = 1
x[coords17] = 1
x[coords18] = 1
x[coords19] = 1
x[coords20] = 1
x[coords21] = 1
x[coords22] = 1
x[coords23] = 1
x[coords24] = 1
x[coords25] = 1
x[coords26] = 1
x[coords27] = 1
x[coords28] = 1
x[coords29] = 1
x[coords30] = 1
x[coords31] = 1
x[coords32] = 1
x[coords33] = 1
x[coords34] = 1
x[coords35] = 1
x[coords36] = 1
x[coords37] = 1
x[coords38] = 1
x[coords39] = 1
x[coords40] = 1
x[coords41] = 1
x[coords42] = 1
x[coords43] = 1
x[coords44] = 1
x[coords45] = 1
x[coords46] = 1
x[coords47] = 1
x[coords48] = 1
x[coords49] = 1
x[coords50] = 1
x[coords51] = 1
x[coords52] = 1
x[coords53] = 1
x[coords54] = 1
x[coords55] = 1
x[coords56] = 1
x[coords57] = 1
x[coords58] = 1
x[coords59] = 1
x[coords60] = 1
x[coords61] = 1
x[coords62] = 1
x[coords63] = 1
x[coords64] = 1
x[coords65] = 1
x[coords66] = 1
x[coords67] = 1
x[coords68] = 1
x[coords69] = 1
x[coords70] = 1
x[coords71] = 1
x[coords72] = 1
x[coords73] = 1
x[coords74] = 1
x[coords75] = 1
x[coords76] = 1
x[coords77] = 1
x[coords78] = 1
x[coords79] = 1

# making values array into image
nii_img = nib.Nifti1Image(x, affine=base_img.affine, header=base_img.header)

# %%
# plotting image for default network
y = nplot.plot_roi(nii_img, img.slicer[:, :, :, 200], cut_coords = (-48, -64, 32), colorbar=True, alpha = 0.8, black_bg=False, cbar_tick_format="%.2g")

# %%
DAN_col = [59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283]

# isolating default attention network (DAN) ROIs from LR1 scan, averaging, and scaling
os.chdir('/data/hcp_working_folder/tdhore2/data_rfMRI/106319/func')
npzfile = np.load('ts_106319.npz')
scan = npzfile['LR1']
DAN_data = scan[:, DAN_col]
DAN_avg = DAN_data.mean(axis=0)
DAN_avg = DAN_avg * 100000

# finding coordinates of each ROI in DAN
arr = np.array(base_img.dataobj)
coords1 = np.where(arr == 60)
coords2 = np.where(arr == 61)
coords3 = np.where(arr == 62)
coords4 = np.where(arr == 63)
coords5 = np.where(arr == 64)
coords6 = np.where(arr == 65)
coords7 = np.where(arr == 66)
coords8 = np.where(arr == 67)
coords9 = np.where(arr == 68)
coords10 = np.where(arr == 69)
coords11 = np.where(arr == 70)
coords12 = np.where(arr == 71)
coords13 = np.where(arr == 72)
coords14 = np.where(arr == 73)
coords15 = np.where(arr == 74)
coords16 = np.where(arr == 75)
coords17 = np.where(arr == 76)
coords18 = np.where(arr == 77)
coords19 = np.where(arr == 78)
coords20 = np.where(arr == 79)
coords21 = np.where(arr == 80)
coords22 = np.where(arr == 81)
coords23 = np.where(arr == 82)
coords24 = np.where(arr == 83)
coords25 = np.where(arr == 84)
coords26 = np.where(arr == 85)
coords27 = np.where(arr == 259)
coords28 = np.where(arr == 260)
coords29 = np.where(arr == 261)
coords30 = np.where(arr == 262)
coords31 = np.where(arr == 263)
coords32 = np.where(arr == 264)
coords33 = np.where(arr == 265)
coords34 = np.where(arr == 266)
coords35 = np.where(arr == 267)
coords36 = np.where(arr == 268)
coords37 = np.where(arr == 269)
coords38 = np.where(arr == 270)
coords39 = np.where(arr == 271)
coords40 = np.where(arr == 272)
coords41 = np.where(arr == 273)
coords42 = np.where(arr == 274)
coords43 = np.where(arr == 275)
coords44 = np.where(arr == 276)
coords45 = np.where(arr == 277)
coords46 = np.where(arr == 278)
coords47 = np.where(arr == 279)
coords48 = np.where(arr == 280)
coords49 = np.where(arr == 281)
coords50 = np.where(arr == 282)
coords51 = np.where(arr == 283)
coords52 = np.where(arr == 284)

# setting DAN ROI coordinates with averaged value while other ROIs remain with a value of 0
x = np.zeros((91, 109, 91))
x[coords1] = DAN_avg[0]
x[coords2] = DAN_avg[1]
x[coords3] = DAN_avg[2]
x[coords4] = DAN_avg[3]
x[coords5] = DAN_avg[4]
x[coords6] = DAN_avg[5]
x[coords7] = DAN_avg[6]
x[coords8] = DAN_avg[9]
x[coords9] = DAN_avg[8]
x[coords10] = DAN_avg[9]
x[coords11] = DAN_avg[10]
x[coords12] = DAN_avg[11]
x[coords13] = DAN_avg[12]
x[coords14] = DAN_avg[13]
x[coords15] = DAN_avg[14]
x[coords16] = DAN_avg[15]
x[coords17] = DAN_avg[16]
x[coords18] = DAN_avg[17]
x[coords19] = DAN_avg[18]
x[coords20] = DAN_avg[19]
x[coords21] = DAN_avg[20]
x[coords22] = DAN_avg[21]
x[coords23] = DAN_avg[22]
x[coords24] = DAN_avg[23]
x[coords25] = DAN_avg[24]
x[coords26] = DAN_avg[25]
x[coords27] = DAN_avg[26]
x[coords28] = DAN_avg[27]
x[coords29] = DAN_avg[28]
x[coords30] = DAN_avg[29]
x[coords31] = DAN_avg[30]
x[coords32] = DAN_avg[31]
x[coords33] = DAN_avg[32]
x[coords34] = DAN_avg[33]
x[coords35] = DAN_avg[34]
x[coords36] = DAN_avg[35]
x[coords37] = DAN_avg[36]
x[coords38] = DAN_avg[37]
x[coords39] = DAN_avg[38]
x[coords40] = DAN_avg[39]
x[coords41] = DAN_avg[40]
x[coords42] = DAN_avg[41]
x[coords43] = DAN_avg[42]
x[coords44] = DAN_avg[43]
x[coords45] = DAN_avg[44]
x[coords46] = DAN_avg[45]
x[coords47] = DAN_avg[46]
x[coords48] = DAN_avg[47]
x[coords49] = DAN_avg[48]
x[coords50] = DAN_avg[49]
x[coords51] = DAN_avg[50]
x[coords52] = DAN_avg[51]

# plotting DAN network relative average activity
nii_img = nib.Nifti1Image(x, affine=base_img.affine, header=base_img.header)
y = nplot.plot_roi(nii_img, img.slicer[:, :, :, 200], cut_coords = (-44, -42, -22), colorbar=True, alpha = 0.8, vmin=-10, vmax=11, black_bg=False, cbar_tick_format="%.2g")

# %%
LN_col = [108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323]

# isolating limbic network (LN) ROIs from LR1 scan, averaging, and scaling
os.chdir('/data/hcp_working_folder/tdhore2/data_rfMRI/106319/func')
npzfile = np.load('ts_106319.npz')
scan = npzfile['LR1']
LN_data = scan[:, LN_col]
LN_ag = LN_data.mean(axis=0)
LN_avg = LN_ag * 100000

# finding coordinates of each ROI in LN
arr = np.array(base_img.dataobj)
coords1 = np.where(arr == 109)
coords2 = np.where(arr == 110)
coords3 = np.where(arr == 111)
coords4 = np.where(arr == 112)
coords5 = np.where(arr == 113)
coords6 = np.where(arr == 114)
coords7 = np.where(arr == 115)
coords8 = np.where(arr == 116)
coords9 = np.where(arr == 117)
coords10 = np.where(arr == 118)
coords11 = np.where(arr == 119)
coords12 = np.where(arr == 120)
coords13 = np.where(arr == 313)
coords14 = np.where(arr == 314)
coords15 = np.where(arr == 315)
coords16 = np.where(arr == 316)
coords17 = np.where(arr == 317)
coords18 = np.where(arr == 318)
coords19 = np.where(arr == 319)
coords20 = np.where(arr == 320)
coords21 = np.where(arr == 321)
coords22 = np.where(arr == 322)
coords23 = np.where(arr == 323)
coords24 = np.where(arr == 324)

# setting LN ROI coordinates with averaged value while other ROIs remain with a value of 0
x = np.zeros((91, 109, 91))
x[coords1] = LN_avg[0]
x[coords2] = LN_avg[1]
x[coords3] = LN_avg[2]
x[coords4] = LN_avg[3]
x[coords5] = LN_avg[4]
x[coords6] = LN_avg[5]
x[coords7] = LN_avg[6]
x[coords8] = LN_avg[7]
x[coords9] = LN_avg[8]
x[coords10] = LN_avg[9]
x[coords11] = LN_avg[10]
x[coords12] = LN_avg[11]
x[coords13] = LN_avg[12]
x[coords14] = LN_avg[13]
x[coords15] = LN_avg[14]
x[coords16] = LN_avg[15]
x[coords17] = LN_avg[16]
x[coords18] = LN_avg[17]
x[coords19] = LN_avg[18]
x[coords20] = LN_avg[19]
x[coords21] = LN_avg[20]
x[coords22] = LN_avg[21]
x[coords23] = LN_avg[22]
x[coords24] = LN_avg[23]

# plotting LN network relative average activity
nii_img = nib.Nifti1Image(x, affine=base_img.affine, header=base_img.header)
y = nplot.plot_roi(nii_img, img.slicer[:, :, :, 200], cut_coords = (-12, 24, -20), colorbar=True, alpha = 0.8, vmin=-10, vmax=11, black_bg=False, cbar_tick_format="%.2g")

# %%
default_col = [148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389]

# isolating default network ROIs from LR1 scan, averaging, and scaling
os.chdir('/data/hcp_working_folder/tdhore2/data_rfMRI/106319/func')
npzfile = np.load('ts_106319.npz')
scan = npzfile['LR1']
def_data = scan[:, default_col]
def_ag = def_data.mean(axis=0)
def_avg = def_ag * 100000

# finding coordinates of each ROI in default network
arr = np.array(base_img.dataobj)
coords1 = np.where(arr == 149)
coords2 = np.where(arr == 150)
coords3 = np.where(arr == 151)
coords4 = np.where(arr == 152)
coords5 = np.where(arr == 153)
coords6 = np.where(arr == 154)
coords7 = np.where(arr == 155)
coords8 = np.where(arr == 156)
coords9 = np.where(arr == 157)
coords10 = np.where(arr == 158)
coords11 = np.where(arr == 159)
coords12 = np.where(arr == 160)
coords13 = np.where(arr == 161)
coords14 = np.where(arr == 162)
coords15 = np.where(arr == 163)
coords16 = np.where(arr == 164)
coords17 = np.where(arr == 165)
coords18 = np.where(arr == 166)
coords19 = np.where(arr == 167)
coords20 = np.where(arr == 168)
coords21 = np.where(arr == 169)
coords22 = np.where(arr == 170)
coords23 = np.where(arr == 171)
coords24 = np.where(arr == 172)
coords25 = np.where(arr == 173)
coords26 = np.where(arr == 174)
coords27 = np.where(arr == 175)
coords28 = np.where(arr == 176)
coords29 = np.where(arr == 177)
coords30 = np.where(arr == 178)
coords31 = np.where(arr == 179)
coords32 = np.where(arr == 180)
coords33 = np.where(arr == 181)
coords34 = np.where(arr == 182)
coords35 = np.where(arr == 183)
coords36 = np.where(arr == 184)
coords37 = np.where(arr == 185)
coords38 = np.where(arr == 186)
coords39 = np.where(arr == 187)
coords40 = np.where(arr == 188)
coords41 = np.where(arr == 189)
coords42 = np.where(arr == 190)
coords43 = np.where(arr == 191)
coords44 = np.where(arr == 192)
coords45 = np.where(arr == 193)
coords46 = np.where(arr == 194)
coords47 = np.where(arr == 358)
coords48 = np.where(arr == 359)
coords49 = np.where(arr == 360)
coords50 = np.where(arr == 361)
coords51 = np.where(arr == 362)
coords52 = np.where(arr == 363)
coords53 = np.where(arr == 364)
coords54 = np.where(arr == 365)
coords55 = np.where(arr == 366)
coords56 = np.where(arr == 367)
coords57 = np.where(arr == 368)
coords58 = np.where(arr == 369)
coords59 = np.where(arr == 370)
coords60 = np.where(arr == 371)
coords61 = np.where(arr == 372)
coords62 = np.where(arr == 373)
coords63 = np.where(arr == 374)
coords64 = np.where(arr == 375)
coords65 = np.where(arr == 376)
coords66 = np.where(arr == 377)
coords67 = np.where(arr == 378)
coords68 = np.where(arr == 379)
coords69 = np.where(arr == 380)
coords70 = np.where(arr == 381)
coords71 = np.where(arr == 382)
coords72 = np.where(arr == 383)
coords73 = np.where(arr == 384)
coords74 = np.where(arr == 385)
coords75 = np.where(arr == 386)
coords76 = np.where(arr == 387)
coords77 = np.where(arr == 388)
coords78 = np.where(arr == 389)
coords79 = np.where(arr == 390)

# setting default network ROI coordinates with averaged value while other ROIs remain with a value of 0
x = np.zeros((91, 109, 91))
x[coords1] = def_avg[0]
x[coords2] = def_avg[1]
x[coords3] = def_avg[2]
x[coords4] = def_avg[3]
x[coords5] = def_avg[4]
x[coords6] = def_avg[5]
x[coords7] = def_avg[6]
x[coords8] = def_avg[7]
x[coords9] = def_avg[8]
x[coords10] = def_avg[9]
x[coords11] = def_avg[10]
x[coords12] = def_avg[11]
x[coords13] = def_avg[12]
x[coords14] = def_avg[13]
x[coords15] = def_avg[14]
x[coords16] = def_avg[15]
x[coords17] = def_avg[16]
x[coords18] = def_avg[17]
x[coords19] = def_avg[18]
x[coords20] = def_avg[19]
x[coords21] = def_avg[20]
x[coords22] = def_avg[21]
x[coords23] = def_avg[22]
x[coords24] = def_avg[23]
x[coords25] = def_avg[24]
x[coords26] = def_avg[25]
x[coords27] = def_avg[26]
x[coords28] = def_avg[27]
x[coords29] = def_avg[28]
x[coords30] = def_avg[29]
x[coords31] = def_avg[30]
x[coords32] = def_avg[31]
x[coords33] = def_avg[32]
x[coords34] = def_avg[33]
x[coords35] = def_avg[34]
x[coords36] = def_avg[35]
x[coords37] = def_avg[36]
x[coords38] = def_avg[37]
x[coords39] = def_avg[38]
x[coords40] = def_avg[39]
x[coords41] = def_avg[40]
x[coords42] = def_avg[41]
x[coords43] = def_avg[42]
x[coords44] = def_avg[43]
x[coords45] = def_avg[44]
x[coords46] = def_avg[45]
x[coords47] = def_avg[46]
x[coords48] = def_avg[47]
x[coords49] = def_avg[48]
x[coords50] = def_avg[49]
x[coords51] = def_avg[50]
x[coords52] = def_avg[51]
x[coords53] = def_avg[52]
x[coords54] = def_avg[53]
x[coords55] = def_avg[54]
x[coords56] = def_avg[55]
x[coords57] = def_avg[56]
x[coords58] = def_avg[57]
x[coords59] = def_avg[58]
x[coords60] = def_avg[59]
x[coords61] = def_avg[60]
x[coords62] = def_avg[61]
x[coords63] = def_avg[62]
x[coords64] = def_avg[63]
x[coords65] = def_avg[64]
x[coords66] = def_avg[65]
x[coords67] = def_avg[66]
x[coords68] = def_avg[67]
x[coords69] = def_avg[68]
x[coords70] = def_avg[69]
x[coords71] = def_avg[70]
x[coords72] = def_avg[71]
x[coords73] = def_avg[72]
x[coords74] = def_avg[73]
x[coords75] = def_avg[74]
x[coords76] = def_avg[75]
x[coords77] = def_avg[76]
x[coords78] = def_avg[77]
x[coords79] = def_avg[78]

# plotting default network relative average activity
nii_img = nib.Nifti1Image(x, affine=base_img.affine, header=base_img.header)
y = nplot.plot_roi(nii_img, img.slicer[:, :, :, 200], cut_coords = (-48, -64, 32), colorbar=True, alpha = 0.8, vmin=-10, vmax=11, black_bg=False, cbar_tick_format="%.2g")

# %%
# average and scaling timeseries for each ROI
os.chdir('/data/hcp_working_folder/tdhore2/ts')
npzfile = np.load('ts_194746.npz')
scan = npzfile['LR1']
ag = scan.mean(axis=0)
avg = ag * 100000

# plotting average activity of each ROI
arr = np.array(base_img.dataobj)
x = np.zeros((91, 109, 91))
for roi in range(0,399):
    coords = np.where(arr == (roi + 1))
    x[coords] = avg[roi]
nii_img = nib.Nifti1Image(x, affine=base_img.affine, header=base_img.header)
y = nplot.plot_roi(nii_img, img.slicer[:, :, :, 200], cut_coords = (-48, -64, 32), colorbar=True, alpha = 0.8, vmin=-10, vmax=11, black_bg=False, cbar_tick_format="%.2g")
