# %%
# libraries
import os 
import numpy as np
import matplotlib.pyplot as plt

# %%
# plotting average timeseries of default network of 12 subjects
subs = ['106319', '123117', '211922', '178142', '562446', '704238', '180230', '168240', '129331', '419239', '154330', '137128']
idx_col = [148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389]
fig, ax = plt.subplots(nrows=4, ncols=3, figsize=(20,8))
plt.subplots_adjust(hspace = 0.5)
plt.suptitle('avg ts of default network of 12 subjects’ Rest1_LR session')

for sub in range(0,12):
    os.chdir('/data/hcp_working_folder/tdhore2/ts/' + subs[sub] + '/func')
    plt.subplot(4, 3, sub+1)
    npzfile = np.load('ts_' + subs[sub] + '.npz')
    LR1 = npzfile['LR1']
    LR1_data = LR1[:, idx_col]
    data_avg = LR1_data.mean(axis=1)  
    plt.plot(data_avg)
    plt.title('sub' + subs[sub])
plt.show()

# %%
# plotting average functional activation of DAN, LN, and default network for all scans for four subjects
subs = ['106319', '123117', '211922']
scans = ['LR1', 'LR2', 'RL1', 'RL2']
pts = ['DAN', 'LN', 'def']
DAN_col = [59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283]
LN_col = [108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323]
default_col = [148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389]
fig, ax = plt.subplots(nrows=4, ncols=3, figsize=(20,8))
plt.subplots_adjust(hspace = 0.5)
plt.suptitle('average functional activation')

for sub in range(0,3):
    os.chdir('/data/hcp_working_folder/tdhore2/data_rfMRI/' + subs[sub] + '/func')
    npzfile = np.load('ts_' + subs[sub] + '.npz')
    for sess in range(0,4):
        scan = npzfile[scans[sess]]
        DAN_data = scan[:, DAN_col]
        DAN_avg = DAN_data.mean(axis=1)
        DAN_point = np.average(DAN_avg)
        LN_data = scan[:, LN_col]
        LN_avg = LN_data.mean(axis=1)
        LN_point = np.average(LN_avg)
        default_data = scan[:, default_col]
        default_avg = default_data.mean(axis=1)
        default_point = np.average(default_avg)
        data = [DAN_point, LN_point, default_point]
        plt.subplot(4, 3, (sub+1)+(3*sess))
        plt.plot(pts, data)
        plt.title('sub' + subs[sub] + ' ' + scans[sess])
plt.show()

# %%
# plotting normalized default network BOLD signal for two subjects
subs = ['106319', '100408']
idx_col = [148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389]
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(30,20))
plt.subplots_adjust(hspace = 0.3)

for sub in range(0,1):
    os.chdir('/data/hcp_working_folder/tdhore2/ts')
    plt.subplot(2, 1, sub+1)
    npzfile = np.load('ts_' + subs[sub] + '.npz')
    LR1 = npzfile['LR1']
    LR1_data = LR1[:, idx_col]
    data_avg = LR1_data.mean(axis=1) 
    plt.xlabel ('Time')
    plt.ylabel ('Normalized Value')
    plt.plot(data_avg)
    plt.title('Subject ' + subs[sub])
plt.show()
